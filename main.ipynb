# %% [markdown]
# # LLM from Scratch
#
# Notebook entry point for the project. Use the notebooks in `pretrain/` to train and test the tokenizer on Google Colab.

# %%
def main():
    print("LLM from Scratch - starting soon")

# %%
main()
